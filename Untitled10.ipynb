# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report , accuracy_score
from sklearn.model_selection import train_test_split

print("importing is done")
# Out:
# importing is done

# %%
df = pd.read_csv('/content/heart.csv')

# %%
df.sample(10, random_state=11)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 207   60    0   0     150   258    0        0       157     0      2.6    1
# 12    49    1   1     130   266    0        1       171     0      0.6    2
# 282   59    1   2     126   218    1        1       134     0      2.2    1
# 297   59    1   0     164   176    1        0        90     0      1.0    1
# 60    71    0   2     110   265    1        0       130     0      0.0    2
# 102   63    0   1     140   195    0        1       179     0      0.0    2
# 183   58    1   2     112   230    0        0       165     0      2.5    1
# 136   60    0   2     120   178    1        1        96     0      0.0    2
# 271   61    1   3     134   234    0        1       145     0      2.6    1
# 39    65    0   2     160   360    0        0       151     0      0.8    2
#
#      caa  thall  output
# 207    2      3       0
# 12     0      2       1
# 282    1      1       0
# 297    2      1       0
# ...

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trtbps       49
# chol        152
# fbs           2
# restecg       3
# thalachh     91
# exng          2
# oldpeak      40
# slp           3
# caa           5
# thall         4
# output        2
# dtype: int64

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.hist(figsize=(16, 20), bins=40, xlabelsize=6, ylabelsize=6);

# %%
X = df.drop('output', axis=1)
y = df['output']

# %%
cat_cols = ['sex','exng','caa','cp','fbs','restecg','slp','thall']
con_cols = ["age","trtbps","chol","thalachh","oldpeak"]
target_col = ["output"]
print("The categorial cols are : ", cat_cols)
print("The continuous cols are : ", con_cols)
print("The target variable is :  ", target_col)
# Out:
# The categorial cols are :  ['sex', 'exng', 'caa', 'cp', 'fbs', 'restecg', 'slp', 'thall']
# The continuous cols are :  ['age', 'trtbps', 'chol', 'thalachh', 'oldpeak']
# The target variable is :   ['output']

# %%
df_corr = df[con_cols].corr().transpose()
df_corr
# Out:
#                age    trtbps      chol  thalachh   oldpeak
# age       1.000000  0.279351  0.213678 -0.398522  0.210013
# trtbps    0.279351  1.000000  0.123174 -0.046698  0.193216
# chol      0.213678  0.123174  1.000000 -0.009940  0.053952
# thalachh -0.398522 -0.046698 -0.009940  1.000000 -0.344187
# oldpeak   0.210013  0.193216  0.053952 -0.344187  1.000000

# %%
data = df.drop("output",axis=1)
correlation_matrix = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='output', palette="PuBu", hue='sex')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df, x="sex", y="age", hue="output", palette="pastel", edgecolor='black')
plt.title("distribution of age and gender for each output")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))

sns.histplot(df["age"],bins=30,kde=True,color="lightblue",ax=ax)

ax.set_xlabel ("age")
ax.set_ylabel ("count/denesity")
ax.set_title  ("Age distripution histogram with denisity curve")
ax.legend(["Denesity_curve","Histogram"])

plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot( 1 , 2 , 1 )
sns.countplot(data = df , x ="fbs" , palette="PuBu")
plt.title("fasting blood sugar levels")
plt.xticks(rotation=45)
plt.xlabel("fasting_blood_sugar",labelpad=35,fontsize=15)
plt.tight_layout()
# Out:
# <ipython-input-24-fe7fa50a00e0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df , x ="fbs" , palette="PuBu")

# %%
numerical_columns = df.select_dtypes(include=['number'])

numerical_columns.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
numerical_useful =['sex', 'cp', 'chol', 'fbs', 'restecg', 'thalachh',
       'exng', 'slp', 'caa', 'thall', 'output']


for col in numerical_useful:
    d_type = df[col].dtype

    if d_type != "object" and (df[col] > 1).any().any():
        plt.figure(figsize=(8, 4))
        sns.histplot([col], bins=50, kde=True)
        plt.title(f"Distribution of {col}")
        plt.xlabel(f'{col}')
        plt.show()

    counts =df[col].value_counts()
    print(f"Counts for {col}:")
    print(counts)
    print("============================================================")
# Out:
# Counts for sex:
# 1    207
# 0     96
# Name: sex, dtype: int64
# ...
# Counts for cp:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64
# ...
# Counts for chol:
# 204    6
# 197    6
# 234    6
# 269    5
# 254    5
#       ..
# 284    1
# 224    1
# 167    1
# 276    1
# 131    1
# Name: chol, Length: 152, dtype: int64
# ...
# Counts for fbs:
# 0    258
# 1     45
# Name: fbs, dtype: int64
# ...
# Counts for restecg:
# 1    152
# 0    147
# 2      4
# Name: restecg, dtype: int64
# ...
# Counts for thalachh:
# 162    11
# 160     9
# 163     9
# 152     8
# 173     8
#        ..
# 202     1
# 184     1
# 121     1
# 192     1
# 90      1
# Name: thalachh, Length: 91, dtype: int64
# ...
# Counts for exng:
# 0    204
# 1     99
# Name: exng, dtype: int64
# ...
# Counts for slp:
# 2    142
# 1    140
# 0     21
# Name: slp, dtype: int64
# ...
# Counts for caa:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: caa, dtype: int64
# ...
# Counts for thall:
# 2    166
# 3    117
# 1     18
# 0      2
# ...

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.2, random_state=2)

# %%
RF_model = RandomForestClassifier(n_estimators= 150)
RF_model.fit(X_train , y_train)
# Out:
# RandomForestClassifier(n_estimators=150)

# %%
RF_model.score(X_train , y_train)
# Out:
# 1.0

# %%
RF_pred = RF_model.predict(X_test)

# %%
RF_acc = accuracy_score(y_test , RF_pred)

# %%
print(classification_report(y_test , RF_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90        32
#            1       0.83      1.00      0.91        29
#
#     accuracy                           0.90        61
#    macro avg       0.91      0.91      0.90        61
# weighted avg       0.92      0.90      0.90        61

# %%
cm1 = confusion_matrix(y_test,RF_pred)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm1,annot=True)
plt.xlabel('predicted')
plt.ylabel('Truh')
# Out:
# Text(95.72222222222221, 0.5, 'Truh')
